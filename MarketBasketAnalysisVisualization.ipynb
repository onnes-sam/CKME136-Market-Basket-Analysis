# %%
import pandas as pd
import pandasql as ps

# %%
from igraph import *
import re
import pyarrow
data = pd.read_csv("pairings.csv")
Transactions_Results = pd.read_parquet('transactions.parquet', engine='pyarrow')
Transactions_Results['ItemsCount'] = Transactions_Results['items'].apply(len)
match_list = Transactions_Results['items'].tolist()
#MultipleOrderedItemsList = Transactions_Results.loc[Transactions_Results['ItemsCount'] > 1].values.tolist()
#print(MultipleOrderedItemsList)
support_values = {}
confidence_values = {}
for x in data.values:
    matching = [s for s in match_list if x[0] in s]
    support_values[x[0]] = len(matching)/len(match_list)
    #conf_matching = [s for s in MultipleOrderedItemsList if x[0] in s]
    #confidence_values[x[0]] = len(conf_matching)/len(matching)
print(support_values[x[0]])
#for item in Transactions_Results['items']:
    #print(item)
    #if item[0].contains('PEN') == True:
        #print("True")
#for x in data.values:
    #print(x[0])
    #regexp = re.compile(x[0])
    #print(Transactions_Results['items'].str.count(x[0]).sum())
#PDItems = PDTransactions.Description.unique()
PDGraph = Graph()
PDGraph.vs
tr_edges = [tuple(x) for x in data.values]
PDEdges = tr_edges
vertices = set()
for line in PDEdges:
    vertices.update(line)
vertices = sorted(vertices)
PDGraph.add_vertices(vertices)
PDGraph.add_edges(PDEdges)
PDGraph.vs['label'] = [x[0] for x in tr_edges]
layout = PDGraph.layout("kk")
#out = plot(PDGraph, layout = layout, bbox = (10000, 10000), margin = 20)
#out.save('transactions_graph_with_support.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-fbabc313a42b> in <module>
#      11 confidence_values = {}
#      12 for x in data.values:
# ---> 13     matching = [s for s in match_list if x[0] in s]
#      14     support_values[x[0]] = len(matching)/len(match_list)
#      15     #conf_matching = [s for s in MultipleOrderedItemsList if x[0] in s]
#
# <ipython-input-4-fbabc313a42b> in <listcomp>(.0)
#      11 confidence_values = {}
#      12 for x in data.values:
# ---> 13     matching = [s for s in match_list if x[0] in s]
#      14     support_values[x[0]] = len(matching)/len(match_list)
#      15     #conf_matching = [s for s in MultipleOrderedItemsList if x[0] in s]
#
# KeyboardInterrupt:

# %%
print(Transactions_encoded)
# Out:
#                4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# 0      False                           False                           False
# 1      False                           False                           False
# 2      False                           False                           False
# 3      False                           False                           False
# 4      False                           False                           False
# 5      False                           False                           False
# 6      False                           False                           False
# 7      False                           False                            True
# 8      False                           False                            True
# 9      False                           False                           False
# 10     False                           False                           False
# ...

# %%
TwoOrderedItems = Transactions_Results.loc[Transactions_Results['ItemsCount'] == 2].sort_values(by='freq', ascending=False)

# %%
from IPython.display import display, HTML
pd.set_option('display.width', 10000)
display(TwoOrderedItems)
# Out:
#                                                     items  freq  ItemsCount
# 151605  [JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROS...   833           2
# 39630   [GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...   784           2
# 333868  [JUMBO STORAGE BAG SUKI, JUMBO BAG RED RETROSPOT]   733           2
# 393353  [JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...   683           2
# 564079  [LUNCH BAG  BLACK SKULL., LUNCH BAG RED RETROS...   648           2
# 301246  [ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...   646           2
# 416149  [PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...   644           2
# 414531  [PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...   614           2
# 319348  [LUNCH BAG PINK POLKADOT, LUNCH BAG RED RETROS...   613           2
# 152668  [JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG RED...   593           2
# 250702  [LUNCH BAG RED RETROSPOT, JUMBO BAG RED RETROS...   588           2
# ...

# %%
ThreeOrderedItems = Transactions_Results.loc[Transactions_Results['ItemsCount'] == 3].sort_values(by='freq', ascending=False)
display(ThreeOrderedItems)
# Out:
#                                                     items  freq  ItemsCount
# 416150  [PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...   549           3
# 333941  [JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKAD...   416           3
# 39760   [GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...   412           3
# 393432  [JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO STOR...   391           3
# 393410  [JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...   380           3
# 319408  [LUNCH BAG PINK POLKADOT, LUNCH BAG  BLACK SKU...   362           3
# 416314  [PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...   346           3
# 316846  [JUMBO BAG WOODLAND ANIMALS, JUMBO BAG PINK PO...   343           3
# 81900   [WOODLAND CHARLOTTE BAG, CHARLOTTE BAG SUKI DE...   337           3
# 414588  [PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...   337           3
# 157390  [STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG SUKI ...   336           3
# ...

# %%
pd.set_option('display.max_colwidth', -1)
MostOrderedItems = Transactions_Results.sort_values(by='ItemsCount', ascending=False)
display(MostOrderedItems['items'].head(5))
# Out:
# 46141     [RED RETROSPOT OVEN GLOVE , RED RETROSPOT PEG BAG, CHILLI LIGHTS, STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK POLKADOT, WOODLAND CHARLOTTE BAG, CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARLOTTE BAG, LUNCH BAG CARS BLUE, PACK OF 72 RETROSPOT CAKE CASES, PARTY BUNTING, REGENCY CAKESTAND 3 TIER]
# 287299    [ROUND SNACK BOXES SET OF 4 SKULLS, RED RETROSPOT OVEN GLOVE , RED RETROSPOT PEG BAG, CHILLI LIGHTS, STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK POLKADOT, WOODLAND CHARLOTTE BAG, CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARLOTTE BAG, PACK OF 72 RETROSPOT CAKE CASES, PARTY BUNTING, REGENCY CAKESTAND 3 TIER]
# 47542     [RED RETROSPOT OVEN GLOVE , RED RETROSPOT PEG BAG, BOX OF 24 COCKTAIL PARASOLS, STRAWBERRY CHARLOTTE BAG, WOODLAND CHARLOTTE BAG, CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARLOTTE BAG, LUNCH BAG CARS BLUE, PACK OF 72 RETROSPOT CAKE CASES, PARTY BUNTING, REGENCY CAKESTAND 3 TIER]
# ...

# %%
from igraph import *

# %%
g = Graph()
IndividualItems = Transactions_Results['items'].loc[Transactions_Results['ItemsCount'] == 1]
print(Transactions_Results['items'])

# %%
g.vs

# %%
g.add_vertices(3)
g.add_edges([(2,0)])
g.add_edges([(0,1), (1,2)])
print(g)
# Out:
# IGRAPH U--- 3 3 --
# + attr: items (v), freq (e)
# + edges:
# 0--2 0--1 1--2

# %%
import pandas as pd

# %%
PDTransactions = pd.read_csv("C:\Onnesimus_Learning\git-hub-repo\mba-code\dataset.csv")

# %%
PDTransactions.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity      InvoiceDate InvoiceDatewS  UnitPrice  CustomerID         Country
# 0  536365    85123A    WHITE HANGING HEART T-LIGHT HOLDER   6         12/01/2010 8:26  12/01/2010    2.55       17850.0     United Kingdom
# 1  536365    71053     WHITE METAL LANTERN                  6         12/01/2010 8:26  12/01/2010    3.39       17850.0     United Kingdom
# 2  536365    84406B    CREAM CUPID HEARTS COAT HANGER       8         12/01/2010 8:26  12/01/2010    2.75       17850.0     United Kingdom
# 3  536365    84029G    KNITTED UNION FLAG HOT WATER BOTTLE  6         12/01/2010 8:26  12/01/2010    3.39       17850.0     United Kingdom
# 4  536365    84029E    RED WOOLLY HOTTIE WHITE HEART.       6         12/01/2010 8:26  12/01/2010    3.39       17850.0     United Kingdom

# %%
PDItems = PDTransactions.Description.unique()

# %%
PDGraph = Graph()
PDGraph.vs

# %%
PDEdges = Transactions_Results['items'].loc[Transactions_Results['ItemsCount'] == 2]
vertices = set()
for line in PDEdges:
    vertices.update(line)
vertices = sorted(vertices)
PDGraph.add_vertices(vertices)
PDGraph.add_edges(PDEdges)
#PDGraph.es["weight"] = 1
#PDGraph.simplify(combine_edges={"weight": "sum"})

# %%
layout = g.layout("kk")
plot(g, layout = layout, bbox = (300, 300), margin = 20)
